# %%
import numpy as np
import pandas as pd
from sklearn import linear_model

# %%
train_df = pd.read_csv("Boston_Train.csv")
train_df
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age     dis  rad  \
# 0             0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1             1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2             2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3             3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4             4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 346         346  0.06162   0.0   4.39     0  0.442  5.898  52.3  8.0136    3
# 347         347  0.01870  85.0   4.15     0  0.429  6.516  27.7  8.5353    4
# 348         348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4
# 349         349  0.02899  40.0   1.25     0  0.429  6.939  34.5  8.7921    1
# 350         350  0.06211  40.0   1.25     0  0.429  6.490  44.4  8.7921    1
#
#      tax  ptratio   black  lstat  medv
# ...

# %%
y_train = train_df.drop(df.iloc[:,0:len(df.columns)-1],axis=1)
x_train = train_df.iloc[:,1:len(df.columns)-1]

# %%
y_train
# Out:
#      medv
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# ..    ...
# 346  17.2
# 347  23.1
# 348  24.5
# 349  26.6
# 350  22.9
#
# [351 rows x 1 columns]

# %%
x_train
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 346  0.06162   0.0   4.39     0  0.442  5.898  52.3  8.0136    3  352
# 347  0.01870  85.0   4.15     0  0.429  6.516  27.7  8.5353    4  351
# 348  0.01501  80.0   2.01     0  0.435  6.635  29.7  8.3440    4  280
# 349  0.02899  40.0   1.25     0  0.429  6.939  34.5  8.7921    1  335
# 350  0.06211  40.0   1.25     0  0.429  6.490  44.4  8.7921    1  335
#
#      ptratio   black  lstat
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# ...

# %%
test_df = pd.read_csv("Boston_Test.csv")
test_df
# Out:
#      Unnamed: 0     crim    zn  indus  chas    nox     rm   age      dis  rad  \
# 0           351  0.07950  60.0   1.69     0  0.411  6.579  35.9  10.7103    4
# 1           352  0.07244  60.0   1.69     0  0.411  5.884  18.5  10.7103    4
# 2           353  0.01709  90.0   2.02     0  0.410  6.728  36.1  12.1265    5
# 3           354  0.04301  80.0   1.91     0  0.413  5.663  21.9  10.5857    4
# 4           355  0.10659  80.0   1.91     0  0.413  5.936  19.5  10.5857    4
# ..          ...      ...   ...    ...   ...    ...    ...   ...      ...  ...
# 150         501  0.06263   0.0  11.93     0  0.573  6.593  69.1   2.4786    1
# 151         502  0.04527   0.0  11.93     0  0.573  6.120  76.7   2.2875    1
# 152         503  0.06076   0.0  11.93     0  0.573  6.976  91.0   2.1675    1
# 153         504  0.10959   0.0  11.93     0  0.573  6.794  89.3   2.3889    1
# 154         505  0.04741   0.0  11.93     0  0.573  6.030  80.8   2.5050    1
#
# ...

# %%
y_test = test_df.drop(df.iloc[:,0:len(df.columns)-1],axis=1)
x_test = test_df.iloc[:,1:len(df.columns)-1]

# %%
y_test
# Out:
#      medv
# 0    24.1
# 1    18.6
# 2    30.1
# 3    18.2
# 4    20.6
# ..    ...
# 150  22.4
# 151  20.6
# 152  23.9
# 153  22.0
# 154  11.9
#
# [155 rows x 1 columns]

# %%
x_test
# Out:
#         crim    zn  indus  chas    nox     rm   age      dis  rad  tax  \
# 0    0.07950  60.0   1.69     0  0.411  6.579  35.9  10.7103    4  411
# 1    0.07244  60.0   1.69     0  0.411  5.884  18.5  10.7103    4  411
# 2    0.01709  90.0   2.02     0  0.410  6.728  36.1  12.1265    5  187
# 3    0.04301  80.0   1.91     0  0.413  5.663  21.9  10.5857    4  334
# 4    0.10659  80.0   1.91     0  0.413  5.936  19.5  10.5857    4  334
# ..       ...   ...    ...   ...    ...    ...   ...      ...  ...  ...
# 150  0.06263   0.0  11.93     0  0.573  6.593  69.1   2.4786    1  273
# 151  0.04527   0.0  11.93     0  0.573  6.120  76.7   2.2875    1  273
# 152  0.06076   0.0  11.93     0  0.573  6.976  91.0   2.1675    1  273
# 153  0.10959   0.0  11.93     0  0.573  6.794  89.3   2.3889    1  273
# 154  0.04741   0.0  11.93     0  0.573  6.030  80.8   2.5050    1  273
#
#      ptratio   black  lstat
# 0       18.3  370.78   5.49
# 1       18.3  392.33   7.79
# ...

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error

print(mean_squared_error(y_test,y_pred))
# Out:
# 547.5466502116037

# %% [markdown]
# MSE is very high and thus, this model is not very good at predicting housing prices

# %% [markdown]
# ## Conclusion
# Linear Regression is not recommended for prediction of such models
